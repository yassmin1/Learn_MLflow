# %% [markdown]
# ✅ The notebook for **Module 2.1: MLflow Projects Basics**
#
# ## 🎯 **Learning Objectives Expanded**
#
# ### 1️⃣ **Understand What MLflow Projects Are and Why They Matter**
#
# * **What it means:**
#   MLflow Projects are a standardized way to package your ML code—including scripts, environments, and configurations—so that it can be easily shared, run, and reproduced on any machine.
#
# * **Key Concepts:**
#
#   * A project is just a folder (or Git repo) containing your training code and an `MLproject` file.
#   * It can define parameters, environments (via `conda.yaml`), and entry points.
#
# * **Why it matters:**
#   MLflow Projects make your code reproducible and portable, whether you're running it locally, in the cloud, or in automated pipelines. This promotes collaboration and consistent results across different environments.
#
# ---
#
# ### 2️⃣ **Structure a Simple Project with `train.py`, `MLproject`, and `conda.yaml`**
#
# * **What it means:**
#   Building the basic components of a self-contained MLflow Project.
#
# * **Directory Structure:**
#
#   ```
#   my_project/
#   ├── MLproject
#   ├── conda.yaml
#   └── train.py
#   ```
#
# * **File Descriptions:**
#
#   ✅ `train.py`
#   The main training script with argument parsing:
#
#   ```python
#   import argparse
#   def main(alpha):
#       print(f"Training with alpha={alpha}")
#   if __name__ == "__main__":
#       parser = argparse.ArgumentParser()
#       parser.add_argument("--alpha", type=float, default=0.5)
#       args = parser.parse_args()
#       main(args.alpha)
#   ```
#
#   ✅ `MLproject`
#   The project specification file:
#
#   ```yaml
#   name: simple_linear_project
#
#   conda_env: conda.yaml
#
#   entry_points:
#     main:
#       parameters:
#         alpha: {type: float, default: 0.5}
#       command: "python train.py --alpha {alpha}"
#   ```
#
#   ✅ `conda.yaml`
#   The environment file that lists all Python dependencies:
#
#   ```yaml
#   name: simple-env
#   channels:
#     - defaults
#   dependencies:
#     - python=3.9
#     - scikit-learn
#   ```
#
# * **Why it matters:**
#   This structure ensures all collaborators (and machines) run the same code in the same environment with consistent results.
#
# ---
#
# ### 3️⃣ **Learn How to Execute a Parameterized Project Using the MLflow CLI**
#
# * **What it means:**
#   Running your project from the command line with different parameter values and environments using MLflow’s command-line interface.
#
# * **Basic Command:**
#
#   ```bash
#   mlflow run . -P alpha=0.2
#   ```
#
# * **Additional Options:**
#
#   * Run from a Git repo:
#
#     ```bash
#     mlflow run https://github.com/yourname/my_project -P alpha=0.7
#     ```
#   * Use a remote backend (e.g., Databricks, Sagemaker) if configured.
#
# * **What happens under the hood:**
#
#   * MLflow creates a fresh virtual environment based on `conda.yaml`.
#   * It passes the parameter (`alpha=0.2`) to `train.py`.
#   * It logs the run like any other MLflow experiment (can be viewed with the Tracking UI).
#
# * **Why it matters:**
#   This allows anyone to reproduce your experiment by running a single command, ensuring consistency in both code and environment—critical for MLOps and collaboration.

# %%
# 📓 Module 2.1: MLflow Projects Basics
# Goal: Learn how to structure and run MLflow Projects for reproducible ML workflows

# ✅ Step 1: Install MLflow
# !pip install -q mlflow

# ✅ Step 2: Create a directory structure for the MLflow Project
import os
project_name = "mlflow_example_project"
os.makedirs(project_name, exist_ok=True)

# ✅ Step 3: Write a simple training script (train.py) to the project folder
code = '''
import mlflow
import mlflow.sklearn
from sklearn.linear_model import Ridge
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import sys

# Parse alpha from command-line argument
alpha = float(sys.argv[1]) if len(sys.argv) > 1 else 1.0

# Enable autologging
mlflow.sklearn.autolog()

with mlflow.start_run():
    X, y = load_diabetes(return_X_y=True)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    model = Ridge(alpha=alpha)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"Test MSE: {mse:.4f}")
'''

with open(os.path.join(project_name, "train.py"), "w") as f:
    f.write(code)

# ✅ Step 4: Create an MLproject file to define the project structure
mlproject_content = '''
name: RidgeRegressionProject

conda_env: conda.yaml

entry_points:
  main:
    parameters:
      alpha: {type: float, default: 1.0}
    command: "python train.py {alpha}"
'''

with open(os.path.join(project_name, "MLproject"), "w") as f:
    f.write(mlproject_content)

# ✅ Step 5: Write a conda.yaml file defining the environment
conda_yaml = '''
name: mlflow-env
channels:
  - defaults
  - conda-forge
dependencies:
  - python=3.8
  - scikit-learn
  - pip
  - pip:
      - mlflow
'''

with open(os.path.join(project_name, "conda.yaml"), "w") as f:
    f.write(conda_yaml)

# ✅ Step 6: Run the project using MLflow CLI (note: works only in local CLI, not in Colab)
print("\n📦 Project setup complete! You can now run this project locally with:")
print(f"mlflow run {project_name} -P alpha=0.5")
# Out:
# 📦 Project setup complete! You can now run this project locally with:
# mlflow run mlflow_example_project -P alpha=0.5

# %%
# !mlflow run mlflow_example_project -P alpha=0.5
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['C:\\Users\\ryass\\anaconda3\\envs\\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'c:\\Users\\ryass\\OneDrive\\Documents\\GitHub\\MLflow_learn\\MLflow_step_by_step\\mlflow_example_project\\condaenv.ntadszqk.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting mlflow (from -r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading mlflow-2.17.2-py3-none-any.whl.metadata (29 kB)
#
# Collecting mlflow-skinny==2.17.2 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading mlflow_skinny-2.17.2-py3-none-any.whl.metadata (30 kB)
#
# Collecting Flask<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
#
# Collecting alembic!=1.10.0,<2 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
#
# Collecting docker<8,>=4.0.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
#
# Collecting graphene<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
#
# Collecting markdown<4,>=3.3 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
#
# Collecting matplotlib<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
#
# Requirement already satisfied: numpy<3 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (1.24.3)
#
# Collecting pandas<3 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
#
# Collecting pyarrow<18,>=4.0.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading pyarrow-17.0.0-cp38-cp38-win_amd64.whl.metadata (3.4 kB)
#
# Requirement already satisfied: scikit-learn<2 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (1.3.0)
#
# Requirement already satisfied: scipy<2 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (1.10.1)
#
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading sqlalchemy-2.0.42-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
#
# Collecting Jinja2<4,>=3.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
#
# Collecting waitress<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
#
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
#
# Collecting click<9,>=7.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
#
# Collecting cloudpickle<4 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
#
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached databricks_sdk-0.61.0-py3-none-any.whl.metadata (39 kB)
#
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
#
# Collecting importlib-metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
#
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading opentelemetry_api-1.33.1-py3-none-any.whl.metadata (1.6 kB)
#
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading opentelemetry_sdk-1.33.1-py3-none-any.whl.metadata (1.6 kB)
#
# Requirement already satisfied: packaging<25 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (24.1)
#
# Collecting protobuf<6,>=3.12.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading protobuf-5.29.5-cp38-cp38-win_amd64.whl.metadata (592 bytes)
#
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading PyYAML-6.0.2-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
#
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (2.32.3)
#
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
#
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
#
# Collecting importlib-resources (from alembic!=1.10.0,<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
#
# Collecting typing-extensions>=4 (from alembic!=1.10.0,<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
#
# Collecting pywin32>=304 (from docker<8,>=4.0.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading pywin32-311-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
#
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (2.2.3)
#
# Collecting Werkzeug>=3.0.0 (from Flask<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
#
# Collecting itsdangerous>=2.1.2 (from Flask<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
#
# Collecting blinker>=1.6.2 (from Flask<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
#
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
#
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
#
# Collecting python-dateutil<3,>=2.7.0 (from graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
#
# Collecting MarkupSafe>=2.0 (from Jinja2<4,>=3.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
#
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
#
# Collecting cycler>=0.10 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
#
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading fonttools-4.57.0-cp38-cp38-win_amd64.whl.metadata (104 kB)
#
# Collecting kiwisolver>=1.0.1 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading kiwisolver-1.4.7-cp38-cp38-win_amd64.whl.metadata (6.4 kB)
#
# Collecting pillow>=6.2.0 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading pillow-10.4.0-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
#
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
#
# Collecting pytz>=2020.1 (from pandas<3->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
#
# Collecting tzdata>=2022.1 (from pandas<3->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
#
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from scikit-learn<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (1.4.2)
#
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from scikit-learn<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (3.5.0)
#
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading greenlet-3.1.1-cp38-cp38-win_amd64.whl.metadata (3.9 kB)
#
# Collecting colorama (from click<9,>=7.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
#
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
#
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
#
# Collecting zipp>=3.20 (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
#
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
#
# Collecting opentelemetry-semantic-conventions==0.54b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl.metadata (2.5 kB)
#
# Collecting six>=1.5 (from python-dateutil<3,>=2.7.0->graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (3.3.2)
#
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (3.7)
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1)) (2024.8.30)
#
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Downloading wrapt-1.17.2-cp38-cp38-win_amd64.whl.metadata (6.5 kB)
#
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
#
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
#
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
#
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_example_project\condaenv.ntadszqk.requirements.txt (line 1))
#
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
#
# Downloading mlflow-2.17.2-py3-none-any.whl (26.7 MB)
#
#    ---------------------------------------- 0.0/26.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/26.7 MB ? eta -:--:--
#     --------------------------------------- 0.5/26.7 MB 1.3 MB/s eta 0:00:21
#    - -------------------------------------- 1.0/26.7 MB 1.4 MB/s eta 0:00:18
#    - -------------------------------------- 1.3/26.7 MB 1.5 MB/s eta 0:00:18
#    -- ------------------------------------- 1.8/26.7 MB 1.6 MB/s eta 0:00:16
#    --- ------------------------------------ 2.1/26.7 MB 1.6 MB/s eta 0:00:16
#    --- ------------------------------------ 2.4/26.7 MB 1.6 MB/s eta 0:00:16
#    --- ------------------------------------ 2.6/26.7 MB 1.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 3.1/26.7 MB 1.6 MB/s eta 0:00:15
#    ---- ----------------------------------- 3.1/26.7 MB 1.6 MB/s eta 0:00:15
#    ----- ---------------------------------- 3.4/26.7 MB 1.4 MB/s eta 0:00:17
#    ----- ---------------------------------- 3.7/26.7 MB 1.4 MB/s eta 0:00:17
#    ------ --------------------------------- 4.2/26.7 MB 1.5 MB/s eta 0:00:16
#    ------- -------------------------------- 5.0/26.7 MB 1.6 MB/s eta 0:00:14
#    -------- ------------------------------- 5.5/26.7 MB 1.7 MB/s eta 0:00:13
#    --------- ------------------------------ 6.0/26.7 MB 1.7 MB/s eta 0:00:12
#    ---------- ----------------------------- 6.8/26.7 MB 1.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 7.3/26.7 MB 1.9 MB/s eta 0:00:11
#    ----------- ---------------------------- 7.6/26.7 MB 1.9 MB/s eta 0:00:11
#    ------------ --------------------------- 8.1/26.7 MB 1.9 MB/s eta 0:00:10
#    ------------- -------------------------- 8.9/26.7 MB 2.0 MB/s eta 0:00:10
#    -------------- ------------------------- 9.4/26.7 MB 2.0 MB/s eta 0:00:09
#    --------------- ------------------------ 10.2/26.7 MB 2.1 MB/s eta 0:00:09
#    ---------------- ----------------------- 11.0/26.7 MB 2.1 MB/s eta 0:00:08
#    ----------------- ---------------------- 11.8/26.7 MB 2.2 MB/s eta 0:00:07
#    ------------------ --------------------- 12.3/26.7 MB 2.2 MB/s eta 0:00:07
#    ------------------- -------------------- 13.1/26.7 MB 2.3 MB/s eta 0:00:07
#    -------------------- ------------------- 13.9/26.7 MB 2.3 MB/s eta 0:00:06
#    ---------------------- ----------------- 14.9/26.7 MB 2.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 15.7/26.7 MB 2.4 MB/s eta 0:00:05
#    ------------------------ --------------- 16.5/26.7 MB 2.5 MB/s eta 0:00:05
#    ------------------------- -------------- 17.3/26.7 MB 2.5 MB/s eta 0:00:04
#    --------------------------- ------------ 18.1/26.7 MB 2.6 MB/s eta 0:00:04
#    ---------------------------- ----------- 18.9/26.7 MB 2.6 MB/s eta 0:00:04
#    ----------------------------- ---------- 19.9/26.7 MB 2.7 MB/s eta 0:00:03
#    ------------------------------ --------- 20.7/26.7 MB 2.7 MB/s eta 0:00:03
#    -------------------------------- ------- 21.5/26.7 MB 2.7 MB/s eta 0:00:02
#    --------------------------------- ------ 22.5/26.7 MB 2.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 23.6/26.7 MB 2.8 MB/s eta 0:00:02
#    ------------------------------------ --- 24.4/26.7 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 25.2/26.7 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 26.0/26.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  26.7/26.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 26.7/26.7 MB 2.9 MB/s eta 0:00:00
#
# Downloading mlflow_skinny-2.17.2-py3-none-any.whl (5.7 MB)
#
#    ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.7 MB 4.2 MB/s eta 0:00:02
#    ------------ --------------------------- 1.8/5.7 MB 4.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.7 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.2/5.7 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.0/5.7 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.7/5.7 MB 3.9 MB/s eta 0:00:00
#
# Using cached alembic-1.14.1-py3-none-any.whl (233 kB)
#
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
#
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
#
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
#
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#
# Downloading matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
#
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 4.2 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.5 MB 4.2 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.5 MB 4.2 MB/s eta 0:00:02
#    ------------------ --------------------- 3.4/7.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.2/7.5 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.0/7.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 5.8/7.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.8/7.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 4.0 MB/s eta 0:00:00
#
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/10.8 MB 3.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/10.8 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/10.8 MB 3.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/10.8 MB 3.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/10.8 MB 3.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/10.8 MB 3.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/10.8 MB 3.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.0/10.8 MB 3.7 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.8 MB 3.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.6/10.8 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.8 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.8 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/10.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 3.6 MB/s eta 0:00:00
#
# Downloading pyarrow-17.0.0-cp38-cp38-win_amd64.whl (25.2 MB)
#
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.2 MB 4.2 MB/s eta 0:00:06
#    -- ------------------------------------- 1.6/25.2 MB 4.0 MB/s eta 0:00:06
#    --- ------------------------------------ 2.4/25.2 MB 3.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 3.1/25.2 MB 3.9 MB/s eta 0:00:06
#    ------ --------------------------------- 3.9/25.2 MB 3.9 MB/s eta 0:00:06
#    ------- -------------------------------- 5.0/25.2 MB 4.0 MB/s eta 0:00:06
#    --------- ------------------------------ 5.8/25.2 MB 4.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.8/25.2 MB 4.1 MB/s eta 0:00:05
#    ------------ --------------------------- 7.6/25.2 MB 4.1 MB/s eta 0:00:05
#    ------------- -------------------------- 8.7/25.2 MB 4.1 MB/s eta 0:00:05
#    -------------- ------------------------- 9.4/25.2 MB 4.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.5/25.2 MB 4.2 MB/s eta 0:00:04
#    ------------------ --------------------- 11.5/25.2 MB 4.2 MB/s eta 0:00:04
#    ------------------- -------------------- 12.6/25.2 MB 4.2 MB/s eta 0:00:03
#    --------------------- ------------------ 13.6/25.2 MB 4.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.4/25.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------ --------------- 15.5/25.2 MB 4.3 MB/s eta 0:00:03
#    -------------------------- ------------- 16.5/25.2 MB 4.4 MB/s eta 0:00:02
#    --------------------------- ------------ 17.6/25.2 MB 4.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.4/25.2 MB 4.4 MB/s eta 0:00:02
#    ------------------------------ --------- 19.1/25.2 MB 4.3 MB/s eta 0:00:02
#    -------------------------------- ------- 20.2/25.2 MB 4.3 MB/s eta 0:00:02
#    --------------------------------- ------ 21.2/25.2 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.3/25.2 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 23.3/25.2 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  25.2/25.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.2/25.2 MB 4.3 MB/s eta 0:00:00
#
# Downloading sqlalchemy-2.0.42-cp38-cp38-win_amd64.whl (2.1 MB)
#
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.8 MB/s eta 0:00:00
#
# Downloading waitress-3.0.0-py3-none-any.whl (56 kB)
#
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
#
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
#
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
#
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
#
# Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
#
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
#
# Using cached databricks_sdk-0.61.0-py3-none-any.whl (680 kB)
#
# Downloading fonttools-4.57.0-cp38-cp38-win_amd64.whl (1.5 MB)
#
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.3 MB/s eta 0:00:00
#
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
#
# Using cached graphql_core-3.2.6-py3-none-any.whl (203 kB)
#
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
#
# Downloading greenlet-3.1.1-cp38-cp38-win_amd64.whl (298 kB)
#
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
#
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
#
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
#
# Downloading kiwisolver-1.4.7-cp38-cp38-win_amd64.whl (55 kB)
#
# Downloading MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
#
# Downloading opentelemetry_api-1.33.1-py3-none-any.whl (65 kB)
#
# Downloading opentelemetry_sdk-1.33.1-py3-none-any.whl (118 kB)
#
# Downloading opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl (194 kB)
#
# Downloading pillow-10.4.0-cp38-cp38-win_amd64.whl (2.6 MB)
#
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.6 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 4.0 MB/s eta 0:00:00
#
# Downloading protobuf-5.29.5-cp38-cp38-win_amd64.whl (434 kB)
#
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
#
# Downloading pywin32-311-cp38-cp38-win_amd64.whl (9.6 MB)
#
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 4.2 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.6 MB 4.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.6 MB 4.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.6 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.6 MB 4.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/9.6 MB 4.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.6 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.6 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 4.3 MB/s eta 0:00:00
#
# Downloading PyYAML-6.0.2-cp38-cp38-win_amd64.whl (162 kB)
#
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
#
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
#
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
#
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
#
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
#
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
#
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
#
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
#
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
#
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
#
# Downloading wrapt-1.17.2-cp38-cp38-win_amd64.whl (38 kB)
#
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
#
# Installing collected packages: pywin32, pytz, zipp, wrapt, waitress, tzdata, typing-extensions, sqlparse, smmap, six, pyyaml, pyparsing, pyasn1, pyarrow, protobuf, pillow, MarkupSafe, kiwisolver, itsdangerous, greenlet, fonttools, cycler, contourpy, colorama, cloudpickle, cachetools, blinker, Werkzeug, sqlalchemy, rsa, python-dateutil, pyasn1-modules, Mako, Jinja2, importlib-resources, importlib-metadata, graphql-core, gitdb, docker, deprecated, click, pandas, opentelemetry-api, matplotlib, markdown, graphql-relay, google-auth, gitpython, Flask, alembic, opentelemetry-semantic-conventions, graphene, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
#
# Successfully installed Flask-3.0.3 Jinja2-3.1.6 Mako-1.3.10 MarkupSafe-2.1.5 Werkzeug-3.0.6 alembic-1.14.1 blinker-1.8.2 cachetools-5.5.2 click-8.1.8 cloudpickle-3.1.1 colorama-0.4.6 contourpy-1.1.1 cycler-0.12.1 databricks-sdk-0.61.0 deprecated-1.2.18 docker-7.1.0 fonttools-4.57.0 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.1.1 importlib-metadata-8.5.0 importlib-resources-6.4.5 itsdangerous-2.2.0 kiwisolver-1.4.7 markdown-3.7 matplotlib-3.7.5 mlflow-2.17.2 mlflow-skinny-2.17.2 opentelemetry-api-1.33.1 opentelemetry-sdk-1.33.1 opentelemetry-semantic-conventions-0.54b1 pandas-2.0.3 pillow-10.4.0 protobuf-5.29.5 pyarrow-17.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pyparsing-3.1.4 python-dateutil-2.9.0.post0 pytz-2025.2 pywin32-311 pyyaml-6.0.2 rsa-4.9.1 six-1.17.0 smmap-5.0.2 sqlalchemy-2.0.42 sqlparse-0.5.3 typing-extensions-4.13.2 tzdata-2025.2 waitress-3.0.0 wrapt-1.17.2 zipp-3.20.2
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# 2025/08/03 08:53:48 INFO mlflow.utils.conda: === Creating conda environment mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f ===
# 2025/08/03 08:56:33 INFO mlflow.projects.utils: === Created directory C:\Users\ryass\AppData\Local\Temp\tmpewp2m553 for downloading remote URIs passed to arguments of type 'path' ===
# 2025/08/03 08:56:33 INFO mlflow.projects.backend.local: === Running command 'conda activate mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f && python train.py 0.5' in run with ID 'afab7c1ca5f846afbe6045e058d52c24' ===
# Traceback (most recent call last):
#   File "train.py", line 16, in <module>
#     with mlflow.start_run():
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\tracking\fluent.py", line 338, in start_run
#     active_run_obj = client.get_run(existing_run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\tracking\client.py", line 226, in get_run
#     return self._tracking_client.get_run(run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 105, in get_run
#     return self.store.get_run(run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\store\tracking\file_store.py", line 693, in get_run
#     run_info = self._get_run_info(run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\store\tracking\file_store.py", line 721, in _get_run_info
#     run_info = self._get_run_info_from_dir(run_dir)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\store\tracking\file_store.py", line 731, in _get_run_info_from_dir
#     return _read_persisted_run_info_dict(meta)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\store\tracking\file_store.py", line 154, in _read_persisted_run_info_dict
#     return RunInfo.from_dictionary(dict_copy)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-2ced9beaaa4525d5306a92a4f35089d553876b2f\lib\site-packages\mlflow\entities\_mlflow_object.py", line 27, in from_dictionary
#     return cls(**filtered_dict)
# TypeError: __init__() missing 1 required positional argument: 'run_uuid'
# 2025/08/03 08:56:37 ERROR mlflow.cli: === Run (ID 'afab7c1ca5f846afbe6045e058d52c24') failed ===

# %% [markdown]
# ## 📝 Assessment: MLflow Projects Basics
#
# ### 📘 Multiple Choice (Choose the best answer)
#
# **1. What is the main purpose of the `MLproject` file in an MLflow Project?**
# A. To log metrics and parameters
# B. To track model performance over time
# **C. To define how the project should be run and what parameters it uses** ✅
# D. To register models in the model registry
#
# ---
#
# **2. Which command is used to execute an MLflow Project locally with a parameter?**
# A. `mlflow train alpha=0.5`
# **B. `mlflow run <project_path> -P alpha=0.5`** ✅
# C. `python train.py --alpha=0.5`
# D. `mlflow ui run project`
#
# ---
#
# **3. What file in an MLflow Project specifies the Python and library dependencies?**
# A. `requirements.txt`
# B. `MLproject`
# **C. `conda.yaml`** ✅
# D. `run_config.json`
#
# ---
#
# **4. If the MLproject file defines a parameter `alpha` with a default value of 1.0, what happens when no `-P alpha=...` is provided in the `mlflow run` command?**
# A. The run fails
# **B. It uses the default value defined in the MLproject file** ✅
# C. It uses zero as a fallback
# D. It asks the user to input the value interactively
#
# ---
#
# ### ✏️ Short Answer
#
# **5. What are the benefits of structuring your code as an MLflow Project?**
# *Hint: Think reproducibility, environment portability, and standardized execution.*
#
# ---
#
# **6. Why do MLflow Projects typically include a `conda.yaml` file instead of `requirements.txt`?**
# *Hint: Conda can control Python version and non-Python dependencies.*
#
# ---
#
# ### 🧪 Mini Project
#
# **7. Task:**
# You want to train a classification model using MLflow Projects.
#
# * Create a directory with `train.py`, `MLproject`, and `conda.yaml`
# * Add a parameter `max_depth` to control a Decision Tree
# * Use `mlflow.run()` or CLI to run the project with `max_depth=4`
# * Log model, parameters, and accuracy
