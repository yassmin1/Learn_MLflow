# %% [markdown]
#  **Module 2.2: Parameterization in MLflow Projects**
#
#
# ## 🎯 **Learning Objectives Expanded**
#
# ### 1️⃣ **Define and Use Multiple Parameters in an MLflow Project**
#
# * **What it means:**
#   You can specify more than one input parameter in your `MLproject` file, such as `alpha`, `max_iter`, or `model_type`, and use them in your training script.
#
# * **Example `MLproject` file:**
#
#   ```yaml
#   name: parameterized_project
#
#   conda_env: conda.yaml
#
#   entry_points:
#     main:
#       parameters:
#         alpha: {type: float, default: 0.5}
#         max_iter: {type: int, default: 100}
#       command: "python train.py --alpha {alpha} --max_iter {max_iter}"
#   ```
#
# * **How it works:**
#   These parameters are injected into your script when the project runs.
#
# * **Why it matters:**
#   Defining parameters at the project level makes it reusable and flexible for different configurations without modifying the code.
#
# ---
#
# ### 2️⃣ **Pass Parameters at Runtime Using `-P` Flags**
#
# * **What it means:**
#   When running your MLflow Project, you can override parameter defaults by specifying values directly from the command line.
#
# * **Example:**
#
#   ```bash
#   mlflow run . -P alpha=0.1 -P max_iter=500
#   ```
#
# * **What happens:**
#   MLflow parses those flags, passes the values to your script, and logs them automatically.
#
# * **Why it matters:**
#   This allows you to experiment with different configurations quickly—perfect for grid searches or tuning from the CLI or CI/CD pipelines.
#
# ---
#
# ### 3️⃣ **Understand the `MLproject` File Structure with Multiple Parameter Types**
#
# * **What it means:**
#   The `MLproject` file not only defines parameters but also their types (e.g., `int`, `float`, `string`, `file`) and default values.
#
# * **Example with various types:**
#
#   ```yaml
#   entry_points:
#     main:
#       parameters:
#         alpha: {type: float, default: 0.1}
#         max_iter: {type: int, default: 100}
#         tag: {type: string, default: "baseline"}
#         config_path: {type: path}
#       command: >
#         python train.py --alpha {alpha} --max_iter {max_iter}
#                        --tag {tag} --config_path {config_path}
#   ```
#
# * **Why it matters:**
#   This makes your project highly configurable, robust, and ready to handle real-world deployment scenarios where different types of input files or parameters are common.

# %%
# 📓 Module 2.2: Parameterization in MLflow Projects
# Goal: Learn how to define and run MLflow Projects with multiple user-defined parameters.

# ✅ Step 1: Install MLflow
# !pip install -q mlflow

# ✅ Step 2: Set up project folder
import os
project_dir = "mlflow_param_project"
os.makedirs(project_dir, exist_ok=True)

# ✅ Step 3: Write train.py with two parameters: alpha and max_iter
train_code = '''
import mlflow
import mlflow.sklearn
from sklearn.linear_model import Ridge
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import sys

# Read parameters from command-line
alpha = float(sys.argv[1]) if len(sys.argv) > 1 else 1.0
max_iter = int(sys.argv[2]) if len(sys.argv) > 2 else 1000

# Enable autologging
mlflow.sklearn.autolog()

with mlflow.start_run():
    X, y = load_diabetes(return_X_y=True)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    model = Ridge(alpha=alpha, max_iter=max_iter)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"Alpha: {alpha}, Max Iter: {max_iter}, Test MSE: {mse:.4f}")
'''

with open(os.path.join(project_dir, "train.py"), "w") as f:
    f.write(train_code)

# ✅ Step 4: Write the MLproject file with multiple parameters
mlproject_content = '''
name: RidgeRegressionMultiParam

conda_env: conda.yaml

entry_points:
  main:
    parameters:
      alpha: {type: float, default: 1.0}
      max_iter: {type: int, default: 1000}
    command: "python train.py {alpha} {max_iter}"
'''

with open(os.path.join(project_dir, "MLproject"), "w") as f:
    f.write(mlproject_content)

# ✅ Step 5: Write conda.yaml
conda_yaml = '''
name: mlflow-param-env
channels:
  - defaults
  - conda-forge
dependencies:
  - python=3.8
  - scikit-learn
  - pip
  - pip:
      - mlflow
'''

with open(os.path.join(project_dir, "conda.yaml"), "w") as f:
    f.write(conda_yaml)

# ✅ Step 6: Show run command (local use)
print("\n📦 Project created with multiple parameters. Run using:")
print(f"mlflow run {project_dir} -P alpha=0.3 -P max_iter=200")
# Out:
# 📦 Project created with multiple parameters. Run using:
# mlflow run mlflow_param_project -P alpha=0.3 -P max_iter=200

# %%
# !mlflow run mlflow_param_project -P alpha=0.3 -P max_iter=200
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['C:\\Users\\ryass\\anaconda3\\envs\\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'c:\\Users\\ryass\\OneDrive\\Documents\\GitHub\\MLflow_learn\\MLflow_step_by_step\\mlflow_param_project\\condaenv.de068x4h.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting mlflow (from -r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached mlflow-2.17.2-py3-none-any.whl.metadata (29 kB)
#
# Collecting mlflow-skinny==2.17.2 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached mlflow_skinny-2.17.2-py3-none-any.whl.metadata (30 kB)
#
# Collecting Flask<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
#
# Collecting alembic!=1.10.0,<2 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
#
# Collecting docker<8,>=4.0.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
#
# Collecting graphene<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
#
# Collecting markdown<4,>=3.3 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
#
# Collecting matplotlib<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
#
# Requirement already satisfied: numpy<3 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (1.24.3)
#
# Collecting pandas<3 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
#
# Collecting pyarrow<18,>=4.0.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pyarrow-17.0.0-cp38-cp38-win_amd64.whl.metadata (3.4 kB)
#
# Requirement already satisfied: scikit-learn<2 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (1.3.0)
#
# Requirement already satisfied: scipy<2 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (1.10.1)
#
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached sqlalchemy-2.0.42-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
#
# Collecting Jinja2<4,>=3.0 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
#
# Collecting waitress<4 (from mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached waitress-3.0.0-py3-none-any.whl.metadata (4.2 kB)
#
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
#
# Collecting click<9,>=7.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
#
# Collecting cloudpickle<4 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
#
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached databricks_sdk-0.61.0-py3-none-any.whl.metadata (39 kB)
#
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
#
# Collecting importlib-metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
#
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached opentelemetry_api-1.33.1-py3-none-any.whl.metadata (1.6 kB)
#
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached opentelemetry_sdk-1.33.1-py3-none-any.whl.metadata (1.6 kB)
#
# Requirement already satisfied: packaging<25 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (24.1)
#
# Collecting protobuf<6,>=3.12.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached protobuf-5.29.5-cp38-cp38-win_amd64.whl.metadata (592 bytes)
#
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached PyYAML-6.0.2-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
#
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (2.32.3)
#
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
#
# Collecting Mako (from alembic!=1.10.0,<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
#
# Collecting importlib-resources (from alembic!=1.10.0,<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
#
# Collecting typing-extensions>=4 (from alembic!=1.10.0,<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
#
# Collecting pywin32>=304 (from docker<8,>=4.0.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pywin32-311-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
#
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (2.2.3)
#
# Collecting Werkzeug>=3.0.0 (from Flask<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
#
# Collecting itsdangerous>=2.1.2 (from Flask<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
#
# Collecting blinker>=1.6.2 (from Flask<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
#
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
#
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
#
# Collecting python-dateutil<3,>=2.7.0 (from graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
#
# Collecting MarkupSafe>=2.0 (from Jinja2<4,>=3.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
#
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
#
# Collecting cycler>=0.10 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
#
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached fonttools-4.57.0-cp38-cp38-win_amd64.whl.metadata (104 kB)
#
# Collecting kiwisolver>=1.0.1 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached kiwisolver-1.4.7-cp38-cp38-win_amd64.whl.metadata (6.4 kB)
#
# Collecting pillow>=6.2.0 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pillow-10.4.0-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
#
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
#
# Collecting pytz>=2020.1 (from pandas<3->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
#
# Collecting tzdata>=2022.1 (from pandas<3->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
#
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from scikit-learn<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (1.4.2)
#
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from scikit-learn<2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (3.5.0)
#
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached greenlet-3.1.1-cp38-cp38-win_amd64.whl.metadata (3.9 kB)
#
# Collecting colorama (from click<9,>=7.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
#
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
#
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
#
# Collecting zipp>=3.20 (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
#
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
#
# Collecting opentelemetry-semantic-conventions==0.54b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl.metadata (2.5 kB)
#
# Collecting six>=1.5 (from python-dateutil<3,>=2.7.0->graphene<4->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (3.3.2)
#
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (3.7)
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1)) (2024.8.30)
#
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached wrapt-1.17.2-cp38-cp38-win_amd64.whl.metadata (6.5 kB)
#
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
#
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
#
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
#
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.2->mlflow->-r c:\Users\ryass\OneDrive\Documents\GitHub\MLflow_learn\MLflow_step_by_step\mlflow_param_project\condaenv.de068x4h.requirements.txt (line 1))
#
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
#
# Using cached mlflow-2.17.2-py3-none-any.whl (26.7 MB)
#
# Using cached mlflow_skinny-2.17.2-py3-none-any.whl (5.7 MB)
#
# Using cached alembic-1.14.1-py3-none-any.whl (233 kB)
#
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
#
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
#
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
#
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
#
# Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
#
# Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#
# Using cached pyarrow-17.0.0-cp38-cp38-win_amd64.whl (25.2 MB)
#
# Using cached sqlalchemy-2.0.42-cp38-cp38-win_amd64.whl (2.1 MB)
#
# Using cached waitress-3.0.0-py3-none-any.whl (56 kB)
#
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
#
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
#
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
#
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
#
# Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
#
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
#
# Using cached databricks_sdk-0.61.0-py3-none-any.whl (680 kB)
#
# Using cached fonttools-4.57.0-cp38-cp38-win_amd64.whl (1.5 MB)
#
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
#
# Using cached graphql_core-3.2.6-py3-none-any.whl (203 kB)
#
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
#
# Using cached greenlet-3.1.1-cp38-cp38-win_amd64.whl (298 kB)
#
# Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
#
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
#
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
#
# Using cached kiwisolver-1.4.7-cp38-cp38-win_amd64.whl (55 kB)
#
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
#
# Using cached opentelemetry_api-1.33.1-py3-none-any.whl (65 kB)
#
# Using cached opentelemetry_sdk-1.33.1-py3-none-any.whl (118 kB)
#
# Using cached opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl (194 kB)
#
# Using cached pillow-10.4.0-cp38-cp38-win_amd64.whl (2.6 MB)
#
# Using cached protobuf-5.29.5-cp38-cp38-win_amd64.whl (434 kB)
#
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
#
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
#
# Using cached pywin32-311-cp38-cp38-win_amd64.whl (9.6 MB)
#
# Using cached PyYAML-6.0.2-cp38-cp38-win_amd64.whl (162 kB)
#
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
#
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#
# Using cached werkzeug-3.0.6-py3-none-any.whl (227 kB)
#
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
#
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
#
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
#
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
#
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
#
# Using cached zipp-3.20.2-py3-none-any.whl (9.2 kB)
#
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
#
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
#
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
#
# Using cached wrapt-1.17.2-cp38-cp38-win_amd64.whl (38 kB)
#
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
#
# Installing collected packages: pywin32, pytz, zipp, wrapt, waitress, tzdata, typing-extensions, sqlparse, smmap, six, pyyaml, pyparsing, pyasn1, pyarrow, protobuf, pillow, MarkupSafe, kiwisolver, itsdangerous, greenlet, fonttools, cycler, contourpy, colorama, cloudpickle, cachetools, blinker, Werkzeug, sqlalchemy, rsa, python-dateutil, pyasn1-modules, Mako, Jinja2, importlib-resources, importlib-metadata, graphql-core, gitdb, docker, deprecated, click, pandas, opentelemetry-api, matplotlib, markdown, graphql-relay, google-auth, gitpython, Flask, alembic, opentelemetry-semantic-conventions, graphene, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
#
# Successfully installed Flask-3.0.3 Jinja2-3.1.6 Mako-1.3.10 MarkupSafe-2.1.5 Werkzeug-3.0.6 alembic-1.14.1 blinker-1.8.2 cachetools-5.5.2 click-8.1.8 cloudpickle-3.1.1 colorama-0.4.6 contourpy-1.1.1 cycler-0.12.1 databricks-sdk-0.61.0 deprecated-1.2.18 docker-7.1.0 fonttools-4.57.0 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.1.1 importlib-metadata-8.5.0 importlib-resources-6.4.5 itsdangerous-2.2.0 kiwisolver-1.4.7 markdown-3.7 matplotlib-3.7.5 mlflow-2.17.2 mlflow-skinny-2.17.2 opentelemetry-api-1.33.1 opentelemetry-sdk-1.33.1 opentelemetry-semantic-conventions-0.54b1 pandas-2.0.3 pillow-10.4.0 protobuf-5.29.5 pyarrow-17.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pyparsing-3.1.4 python-dateutil-2.9.0.post0 pytz-2025.2 pywin32-311 pyyaml-6.0.2 rsa-4.9.1 six-1.17.0 smmap-5.0.2 sqlalchemy-2.0.42 sqlparse-0.5.3 typing-extensions-4.13.2 tzdata-2025.2 waitress-3.0.0 wrapt-1.17.2 zipp-3.20.2
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# 2025/08/03 16:27:07 INFO mlflow.utils.conda: === Creating conda environment mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b ===
# 2025/08/03 16:29:23 INFO mlflow.projects.utils: === Created directory C:\Users\ryass\AppData\Local\Temp\tmpzya18ko9 for downloading remote URIs passed to arguments of type 'path' ===
# 2025/08/03 16:29:23 INFO mlflow.projects.backend.local: === Running command 'conda activate mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b && python train.py 0.3 200' in run with ID '0516aa1921df45a8b6ea8ac53e293771' ===
# Traceback (most recent call last):
#   File "train.py", line 17, in <module>
#     with mlflow.start_run():
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\tracking\fluent.py", line 338, in start_run
#     active_run_obj = client.get_run(existing_run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\tracking\client.py", line 226, in get_run
#     return self._tracking_client.get_run(run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\tracking\_tracking_service\client.py", line 105, in get_run
#     return self.store.get_run(run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\store\tracking\file_store.py", line 693, in get_run
#     run_info = self._get_run_info(run_id)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\store\tracking\file_store.py", line 721, in _get_run_info
#     run_info = self._get_run_info_from_dir(run_dir)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\store\tracking\file_store.py", line 731, in _get_run_info_from_dir
#     return _read_persisted_run_info_dict(meta)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\store\tracking\file_store.py", line 154, in _read_persisted_run_info_dict
#     return RunInfo.from_dictionary(dict_copy)
#   File "C:\Users\ryass\anaconda3\envs\mlflow-e1fdd3e96956f7e6a5bf9c74d87a0d7ad86c5a0b\lib\site-packages\mlflow\entities\_mlflow_object.py", line 27, in from_dictionary
#     return cls(**filtered_dict)
# TypeError: __init__() missing 1 required positional argument: 'run_uuid'
# 2025/08/03 16:29:31 ERROR mlflow.cli: === Run (ID '0516aa1921df45a8b6ea8ac53e293771') failed ===

# %% [markdown]
# ## 📝 Assessment: Parameterization in Projects
#
# ### 📘 Multiple Choice (Choose the best answer)
#
# **1. How do you pass multiple parameters when running an MLflow Project?**
# A. `mlflow run project.py alpha=0.1 max_iter=200`
# **B. `mlflow run <project_path> -P alpha=0.1 -P max_iter=200`** ✅
# C. `mlflow train --alpha 0.1 --max_iter 200`
# D. `python train.py --alpha 0.1 --max_iter 200`
#
# ---
#
# **2. What happens if you omit a required parameter that doesn't have a default in the `MLproject` file?**
# A. MLflow uses a random value
# B. It skips the parameter
# **C. The run fails with a missing parameter error** ✅
# D. It sets the parameter to 0 by default
#
# ---
#
# **3. In an MLflow `MLproject` file, how are parameter types defined?**
# A. Inside `conda.yaml`
# B. Using Python’s `type()`
# **C. As YAML under the `parameters` block with type annotations** ✅
# D. With `log_param()` during training
#
# ---
#
# **4. Which of the following is a valid `parameters` section in an `MLproject` file?**
#
# ```yaml
# parameters:
#   learning_rate: {type: float, default: 0.01}
#   max_iter: {type: int, default: 100}
# ```
#
# **A. This is valid** ✅
# B. This is invalid – type should be Python types
# C. This is invalid – parameters go in `train.py`
# D. This is invalid – use `requirements.txt` for parameters
#
# ---
#
# ### ✏️ Short Answer
#
# **5. Why is parameterization useful in MLflow Projects?**
# *It allows running experiments with different configurations easily and reproducibly, enabling comparison across hyperparameter settings.*
#
# ---
#
# **6. What’s the difference between setting default values in the `MLproject` file vs providing them at runtime?**
# *Defaults ensure fallback values are available; runtime parameters override them, giving more flexibility during experimentation.*
#
# ---
#
# ### 🧪 Mini Project
#
# **7. Task:**
# Extend the Ridge Regression MLflow Project to accept a third parameter: `solver`
#
# * Add it to the `MLproject` and `train.py`
# * Provide a default value of `"auto"`
# * Run the project with:
#
#   ```bash
#   mlflow run . -P alpha=0.5 -P max_iter=500 -P solver=svd
#   ```
# * Log all parameters and MSE metric
# * Compare results across different solvers
